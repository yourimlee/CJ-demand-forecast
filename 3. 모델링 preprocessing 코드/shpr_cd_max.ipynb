# %%
import numpy as np
import pandas as pd

# %%
# Google Drive Mount

from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/Shareddrives/cj공모전/2021년 미래기술 챌린지_211005/1. 이커머스 FC주문 데이터/
# Out:
# /content/gdrive/Shareddrives/cj공모전/2021년 미래기술 챌린지_211005/1. 이커머스 FC주문 데이터

# %%
# %ls
# Out:
# cluster_label.pkl             fc주문_6월.csv        전체.pkl
# fc주문_통합_수정_1014ver.pkl  fc주문_통합_수정.csv  모델링파일.pkl
# fc주문_3월.csv                fc주문_통합.csv       시계열temp1.csv
# fc주문_4월.csv                fc주문_통합_수정.pkl  시계열temp1.pkl
# fc주문_5월.csv                fc주문_통합_ver2.csv

# %%
final = pd.read_pickle("fc주문_통합_수정.pkl")
final.head(2)
# Out:
#   CORP_ID        REF_ORD_NO BKG_TYP  ...          평균가격      metric cluster
# 0   KX007  2021030365922551       7  ...  14900.000000   134265392     8.0
# 1   KX007  2021030365922951       7  ...  20529.683416  4610261043     0.0
#
# [2 rows x 24 columns]

# %%
pd.set_option('display.max_rows', 12000)

# %%
df1 = final.groupby(['ITEM_CD','SHPR_CD'])['ITEM_QTY'].sum().reset_index()

# %%
df3=df1[df1['ITEM_QTY']<100]

# %%
df3=df3[df3['ITEM_QTY']>10]

# %%
df3[df3['ITEM_CD'].duplicated()]
# Out:
#              ITEM_CD   SHPR_CD  ITEM_QTY
# 107        121174432  90001582        11
# 277        161523952  90001341        18
# 278        161523952  90001441        17
# 279        161523952  90001443        11
# 518       2108751155  90001441        21
# 519       2108751155  90001443        14
# 797       2475138283  90001582        11
# 1010      2756258776  90001443        25
# 1225       309765531  90001441        13
# 1243       310937345  90001582        14
# 1394      3556304880  90001582        17
# 1883       429915183  90001443        16
# 2638      4624382111  90001341        14
# 2640      4624382111  90001443        11
# 2644      4624382111  90001582        19
# 2773      4658408144  90001602        65
# 3080      4733964360  90001341        35
# 3082      4733964360  90001443        17
# 3084      4733964360  90001582        22
# 3572      4802177320  90001341        13
# 3573      4802177320  90001441        12
# 3574      4802177320  90001443        14
# ...

# %%
df4=df1[df1['ITEM_CD']=='8809544011655']
df4
# Out:
#              ITEM_CD   SHPR_CD  ITEM_QTY
# 10969  8809544011655  90001702        84
# 10970  8809544011655  90001705        80

# %%
df4['SHPR_CD'].unique()
# Out:
# array(['90001702', '90001705'], dtype=object)
